# %%
import pandas as pd
import numpy as np
import os
import re

BASE_DIR = os.getcwd()
DIR_NAME = os.path.basename(BASE_DIR)
print(BASE_DIR, DIR_NAME)
while DIR_NAME != "RakutenTeam": 
    BASE_DIR = os.path.realpath(os.path.join(os.path.dirname(__name__), '..'))
    DIR_NAME = os.path.basename(BASE_DIR)
    os.chdir(BASE_DIR)
    DATA_DIR = os.path.join(BASE_DIR, 'data')
    print( BASE_DIR, DATA_DIR, DIR_NAME)
# Out:
# c:\Users\mangg\projects\RakutenTeam\notebook\tests tests
# C:\Users\mangg\projects\RakutenTeam\notebook C:\Users\mangg\projects\RakutenTeam\notebook\data notebook
# C:\Users\mangg\projects\RakutenTeam C:\Users\mangg\projects\RakutenTeam\data RakutenTeam

# %%
IMG_DIR = os.path.join(DATA_DIR, "images", "train")
print(IMG_DIR)
# Out:
# C:\Users\mangg\projects\RakutenTeam\data\images\train

# %%
from src.data_loader import import_data

folder_path = os.path.join(DATA_DIR, "raw")
print(folder_path)
# Out:
# C:\Users\mangg\projects\RakutenTeam\data\raw

# %%
df = import_data(folder_path=folder_path)

# %%
df.head()
# Out:
#    prdtypecode                                        designation  \
# 0           10  Olivia: Personalisiertes Notizbuch / 150 Seite...
# 1         2280  Journal Des Arts (Le) N° 133 Du 28/09/2001 - L...
# 2           50  Grand Stylet Ergonomique Bleu Gamepad Nintendo...
# 3         1280  Peluche Donald - Europe - Disneyland 2000 (Mar...
# 4         2705                               La Guerre Des Tuques
#
#                                          description   productid     imageid
# 0                                                NaN  3804725264  1263597046
# 1                                                NaN   436067568  1008141237
# 2  PILOT STYLE Touch Pen de marque Speedlink est ...   201115110   938777978
# 3                                                NaN    50418756   457047496
# 4  Luc a des id&eacute;es de grandeur. Il veut or...   278535884  1077757786

# %%
from src.features.images.transformers.size_extractor import SizeExtractor

extractor = SizeExtractor(img_folder=IMG_DIR)

extractor.fit_transform(df)
# Out:
#        prdtypecode                                        designation  \
# 0               10  Olivia: Personalisiertes Notizbuch / 150 Seite...
# 1             2280  Journal Des Arts (Le) N° 133 Du 28/09/2001 - L...
# 2               50  Grand Stylet Ergonomique Bleu Gamepad Nintendo...
# 3             1280  Peluche Donald - Europe - Disneyland 2000 (Mar...
# 4             2705                               La Guerre Des Tuques
# ...            ...                                                ...
# 84911           40                        The Sims [ Import Anglais ]
# 84912         2583  Kit piscine acier NEVADA déco pierre Ø 3.50m x...
# 84913         2280  Journal Officiel De La Republique Francaise N°...
# 84914         1560  Table Basse Bois De Récupération Massif Base B...
# 84915         2522  Gomme De Collection 2 Gommes Pinguin Glace Ver...
#
#                                              description   productid  \
# 0                                                    NaN  3804725264
# 1                                                    NaN   436067568
# 2      PILOT STYLE Touch Pen de marque Speedlink est ...   201115110
# 3                                                    NaN    50418756
# 4      Luc a des id&eacute;es de grandeur. Il veut or...   278535884
# ...                                                  ...         ...
# 84911                                                NaN   206719094
# 84912  <b>Description complète :</b><br />Kit piscine...  3065095706
# 84913                                                NaN   440707564
# 84914  <p>Cette table basse a un design unique et con...  3942400296
# 84915                                                NaN    57203227
#
#           imageid                                           img_path  \
# 0      1263597046  C:\Users\mangg\projects\RakutenTeam\data\image...
# 1      1008141237  C:\Users\mangg\projects\RakutenTeam\data\image...
# 2       938777978  C:\Users\mangg\projects\RakutenTeam\data\image...
# 3       457047496  C:\Users\mangg\projects\RakutenTeam\data\image...
# 4      1077757786  C:\Users\mangg\projects\RakutenTeam\data\image...
# ...           ...                                                ...
# 84911   941495734  C:\Users\mangg\projects\RakutenTeam\data\image...
# 84912  1188462883  C:\Users\mangg\projects\RakutenTeam\data\image...
# 84913  1009325617  C:\Users\mangg\projects\RakutenTeam\data\image...
# 84914  1267353403  C:\Users\mangg\projects\RakutenTeam\data\image...
# 84915   684671297  C:\Users\mangg\projects\RakutenTeam\data\image...
#
#              size  actual_size  actual_ratio
# 0      [500, 500]        0.420      0.695238
# 1      [500, 500]        0.548      0.708029
# 2      [500, 500]        0.740      0.972973
# 3      [500, 500]        0.802      0.842893
# 4      [500, 500]        0.610      0.636066
# ...           ...          ...           ...
# 84911  [500, 500]        1.000      0.740000
# 84912  [500, 500]        1.000      1.243781
# 84913  [500, 500]        0.570      0.736842
# 84914  [500, 500]        0.928      1.208333
# 84915  [500, 500]        1.000      1.677852
#
# [84916 rows x 9 columns]
